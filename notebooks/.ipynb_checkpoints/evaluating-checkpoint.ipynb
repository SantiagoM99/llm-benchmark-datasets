# %%
import pandas as pd

data = pd.read_csv('../results.csv')
data["Message"][2]
# Out:
# 'Quantum entanglement is one of the most intriguing and counterintuitive phenomena in quantum physics. It refers to a special kind of connection between two or more quantum particles (like electrons or photons), whereby their individual states become correlated in such a way that the state of one particle cannot be described independently of the state of the other(s)—even if the particles are separated by vast distances.\n\nHere\'s the concept broken down:\n\n### 1. **Quantum States**\nIn quantum mechanics, particles are described by a "quantum state," which encapsulates information such as their position, momentum, spin, and other properties. Before measurement, these properties can exist in a superposition—a combination of all possible states.\n\n### 2. **Entanglement**\nWhen two particles interact, their quantum states can become entangled. Once entangled, the particles behave as a single, unified system, even though they are physically separate. For example, measuring the state o
# ...
